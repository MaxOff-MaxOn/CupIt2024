# %%
# !pip install pandas
# !pip install seaborn
# !pip install statsmodels
# !pip install scikit-learn
# !pip install scipy

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Работа с датасетом (СТАРОЕ + МУСОР)

# %%
data_raw = pd.read_csv('data.csv')

# %%
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995004 entries, 0 to 995003
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   benchmark_id      995004 non-null  object
#  1   benchmark_name    995004 non-null  object
#  2   date_of           995004 non-null  object
#  3   quote             995004 non-null  float64
#  4   ctl_loading       995004 non-null  int64
#  5   ctl_loading_date  995004 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 45.5+ MB

# %%
len (data_raw.benchmark_id.unique())
# Out:
# 516

# %%
len (data_raw.benchmark_name.unique())
# Out:
# 511

# %%
data_raw.head(5)
# Out:
#                            benchmark_id                    benchmark_name  \
# 0  00000000-0000-0000-0000-000000000001                            Ruonia
# 1  005F4F7B-D562-4B0F-BDC9-EB892065A955                         RUGBITR1Y
# 2  03B447D1-2B2D-4AC2-90C1-5DF2935D4FD1  50%RUCBITRBB3Y + 50%RUCBITRBBB3Y
# 3  050C195A-1D74-402F-B36D-63CA40AFE789    60% RUGBITR1Y+40% RUONIA Index
# 4  050C195A-1D74-402F-B36D-63CA40AFE789    60% RUGBITR1Y+40% RUONIA Index
#
#       date_of       quote  ctl_loading ctl_loading_date
# 0  2018-04-09  513.893595  38463471715       2018-04-09
# 1  2018-04-09  153.916680  38463471715       2018-04-09
# 2  2018-04-09   48.649655  38463471715       2018-04-09
# 3  2018-04-09  277.774791  38463471715       2018-04-09
# 4  2018-04-09  277.774791  38463471715       2018-04-09

# %%
df_for_roffl = data_raw.groupby(by = ['benchmark_name'])['benchmark_id'].agg(['unique'])
df_for_roffl['len'] = df_for_roffl['unique'].map(len)
df_for_roffl.loc[df_for_roffl['len'] > 1]
# Out:
#                                                                                             unique  \
# benchmark_name
# 34.44%EMB + 20.42%VCIT + 21.31%NOBL + 23.83%GLD  [0AB1792A-837C-4A1C-9752-06A63057B79E, 295D397...
# 40% EMB + 36% VCIT + 13% NOBL + 11% GLD          [81CEE985-55AC-4ADE-88AC-6A33BAF41A17, AF25F87...
# 40%RUGBITR3Y+60%RUGBITR1Y                        [2D4EF6CD-7300-4AC6-AD2F-6C7C8738A12F, 098AFF7...
# Technology Select Sector Index                   [8D8AADAB-A754-4C02-9C81-0E0B4890856B, 51D93A6...
#
#                                                  len
# benchmark_name
# 34.44%EMB + 20.42%VCIT + 21.31%NOBL + 23.83%GLD    2
# 40% EMB + 36% VCIT + 13% NOBL + 11% GLD            2
# 40%RUGBITR3Y+60%RUGBITR1Y                          3
# Technology Select Sector Index                     2

# %% [markdown]
# ## Группировка данных

# %%
def getgrouped_df(df, group_col, value_col):
    df2 = df.pivot(columns=group_col, values=[value_col])
    df2.columns = [f"{col[1]}" for col in df2.columns]
    df2['date_of'] = df['date_of']
    df2 = df2.groupby('date_of').min()
    df2.reset_index(inplace=True) 
    df2.set_index('date_of', inplace=True)
    return df2

# %%
data = getgrouped_df (data_raw, 'benchmark_id', 'quote')
data
# Out:
#             00000000-0000-0000-0000-000000000001  \
# date_of
# 2018-04-09                            513.893595
# 2018-04-10                            510.579046
# 2018-04-11                            544.724538
# 2018-04-12                            610.296457
# 2018-04-13                            581.447156
# ...                                          ...
# 2024-03-11                                   NaN
# 2024-03-12                                   NaN
# 2024-03-13                                   NaN
# 2024-03-14                                   NaN
# 2024-03-15                                   NaN
#
#
# date_of
# 2018-04-09                                   NaN
# 2018-04-10                                   NaN
# 2018-04-11                                   NaN
# 2018-04-12                                   NaN
# 2018-04-13                                   NaN
# ...                                          ...
# 2024-03-11                            191.697563
# 2024-03-12                            194.411592
# 2024-03-13                            198.669337
# 2024-03-14                                   NaN
# 2024-03-15                            198.669337
#
# [2168 rows x 516 columns]

# %%
data.index = data.index.map(pd.Timestamp)

# %%
data.head(2)
# Out:
#             00000000-0000-0000-0000-000000000001  \
# date_of
# 2018-04-09                            513.893595
# 2018-04-10                            510.579046
#
#             005F4F7B-D562-4B0F-BDC9-EB892065A955  \
# date_of
# 2018-04-09                            153.916680
# 2018-04-10                            157.474457
#
#             023BD1D9-8A68-4ED0-9A3C-ED726A4EF8CF  \
# date_of
# 2018-04-09                            293.910272
# 2018-04-10                            305.293772
#
#             031C5720-6EA0-4D01-9622-D52BBB917D9F  \
# date_of
# 2018-04-09                            436.987241
# 2018-04-10                            450.483250
#
#             036C8B72-AF6B-42A5-BE73-5DD4EC6B2FB9  \
# date_of
# 2018-04-09                            269.521904
# 2018-04-10                            269.521904
#
#             03B447D1-2B2D-4AC2-90C1-5DF2935D4FD1  \
# date_of
# 2018-04-09                             48.649655
# 2018-04-10                             46.954153
#
#             04BEAA55-0009-4C6E-88D2-7CC628D623F0  \
# date_of
# 2018-04-09                            355.278729
# 2018-04-10                            355.278729
#
#             04F366C8-BD16-4650-BEEB-8266E8241DBE  \
# date_of
# 2018-04-09                            360.898977
# 2018-04-10                            365.842685
#
#             050C195A-1D74-402F-B36D-63CA40AFE789  \
# date_of
# 2018-04-09                            277.774791
# 2018-04-10                            273.444512
#
#             0532FCD2-5A26-4ED7-83C1-F482BE949312  ...  \
# date_of                                           ...
# 2018-04-09                             63.836133  ...
# 2018-04-10                             60.138527  ...
#
#             F7B73BEE-2E70-4069-B38A-397B488A65CD  \
# date_of
# 2018-04-09                            268.446849
# 2018-04-10                            268.446849
#
#             F846C875-184D-4862-8C0E-5A5D58E4FD20  \
# date_of
# 2018-04-09                                   NaN
# 2018-04-10                                   NaN
#
#             F8862F06-75B8-4228-AB48-DB8C6D19BC0C  \
# date_of
# 2018-04-09                            512.882199
# 2018-04-10                            512.882199
#
#             FB32952E-FB8D-4285-A4EC-578632AA5580  \
# date_of
# 2018-04-09                             60.564115
# 2018-04-10                             60.564115
#
#             FB5DFAD6-CF72-4C1A-B78C-EE42A1D0BFE0  \
# date_of
# 2018-04-09                                   NaN
# 2018-04-10                                   NaN
#
#             FB659A84-535D-485D-8B6C-3E511B057ABC  \
# date_of
# 2018-04-09                            390.178334
# 2018-04-10                            370.739733
#
#             FCE411C7-6A5C-4AB3-8626-070844143139  \
# date_of
# 2018-04-09                                   NaN
# 2018-04-10                                   NaN
#
#             FD11CE27-B1A1-46E4-B6FE-CDDC4006E8CF  \
# date_of
# 2018-04-09                            118.713494
# 2018-04-10                            118.713494
#
#             FD3C30F6-F7FD-4AD8-94A4-CBBF6734AB62  \
# date_of
# 2018-04-09                            467.472672
# 2018-04-10                            401.220976
#
#             FDD3894E-BD97-45DB-B236-A2DB271FFFDA
# date_of
# 2018-04-09                                   NaN
# 2018-04-10                                   NaN
#
# [2 rows x 516 columns]

# %% [markdown]
# ## Анализ и очистка данных

# %% [markdown]
# Распределение числа пропусков в рядах - некоторые из них являются очень разреженными

# %%
sns.histplot(data.isna().sum(axis=0).to_numpy())
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Это связано с тем, что часть данных относятся к старым периодам, а часть наоборот только к новым. Очевидно, что в рамках решения задачи нам не слишком нужны старые ряды - и мы можем спокойно их отбросить.

# %%
data_ts_info = pd.DataFrame(index = data.columns)

# %%
max_data = []
min_data = []

# %%
for i in data.columns:
    data_vspom = data[i].dropna()
    max_data.append(max(data_vspom.index))
    min_data.append(min(data_vspom.index))

# %% [markdown]
# В данных наблюдается 55 рядов по которым нет записей за последние 2 года.

# %% [markdown]
# По 92 рядам не передаются посылки 3 марта 15 марта.

# %% [markdown]
# ## Количество индексов в определенный день

# %%
data_real_sum_indexes = pd.read_csv("data.csv", parse_dates=["date_of", "ctl_loading_date"]).groupby(["date_of"]).size()

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15, 6))
sns.lineplot(data=data_real_sum_indexes, color = sns.color_palette("Greens")[3])
plt.title('Количество индексов по дням')
plt.xlabel('Дата')
plt.ylabel('Количество индексов')
plt.xlim(data_real_sum_indexes.index[0], data_real_sum_indexes.index[-1])
plt.show()

# %% [markdown]
# ## Посылки и аномалии

# %%
key_column = "agg_quan"

# %%
df_loadings = pd.read_csv('loadings.csv', parse_dates=["date_of", "ctl_loading_date"])
df_loadings.columns
# Out:
# Index(['date_of', 'ctl_loading_date', 'quan', 'quan_no_weak_dub',
#        'quan_no_dub', 'agg_quan', 'agg_quan_no_week_dub', 'agg_quan_no_dub'],
#       dtype='object')

# %%
data_as_ts = df_loadings[key_column]
data_as_ts.index = df_loadings['date_of'].map(pd.Timestamp)
data_as_ts = data_as_ts.sort_index()

# %%
data_as_ts.tail()
# Out:
# date_of
# 2024-03-11    467
# 2024-03-12    458
# 2024-03-13    458
# 2024-03-14    422
# 2024-03-15    458
# Name: agg_quan, dtype: int64

# %%
data_as_ts.plot(figsize = (12, 5))
# Out:
# <AxesSubplot:xlabel='date_of'>

# %%
data_as_ts.loc[data_as_ts > 400].plot(figsize = (15, 5))
# Out:
# <AxesSubplot:xlabel='date_of'>

# %%
data_as_ts
# Out:
# date_of
# 2018-04-09    435
# 2018-04-10    476
# 2018-04-11    458
# 2018-04-12    443
# 2018-04-13    458
#              ...
# 2024-03-11    467
# 2024-03-12    458
# 2024-03-13    458
# 2024-03-14    422
# 2024-03-15    458
# Name: agg_quan, Length: 2295, dtype: int64

# %%
(data_as_ts-data_real_sum_indexes).plot(figsize = (15, 5))
# Out:
# <AxesSubplot:xlabel='date_of'>

# %%
data_anomaly_detection = (data_as_ts-data_real_sum_indexes)

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15, 6))
sns.lineplot(data=data_anomaly_detection.loc[data_anomaly_detection > -10], color = sns.color_palette("Greens")[3])
plt.title('Разница рядов')
plt.xlabel('Дата')
plt.ylabel('Разница')
plt.xlim(data_anomaly_detection.index[0], data_anomaly_detection.index[-1])
plt.show()

# %%
df_detection = df_loadings[[key_column,'date_of']]

# %% [markdown]
# ## Classification

# %%
from sklearn.svm import OneClassSVM
import matplotlib.pyplot as plt

# %%
df_correlation = df_detection

# %%
df_correlation.date_of = df_correlation.date_of.map(pd.Timestamp).apply(lambda x: x.value)/10**9
# Out:
# C:\Users\Максем\AppData\Local\Temp\ipykernel_26460\322975381.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_correlation.date_of = df_correlation.date_of.map(pd.Timestamp).apply(lambda x: x.value)/10**9

# %%
df_correlation
# Out:
#       agg_quan       date_of
# 0          456  1.661904e+09
# 1          450  1.528848e+09
# 2          458  1.698538e+09
# 3          471  1.573517e+09
# 4          463  1.529885e+09
# ...        ...           ...
# 2290       455  1.611878e+09
# 2291       425  1.542499e+09
# 2292       451  1.694218e+09
# 2293       458  1.634602e+09
# 2294       447  1.630109e+09
#
# [2295 rows x 2 columns]

# %%
clf = OneClassSVM(nu = 0.02, kernel = 'linear')
data_classes = clf.fit_predict(pd.DataFrame(df_correlation[key_column]))
sns.scatterplot(data=df_correlation, x="date_of", y=key_column, hue = data_classes, color = sns.color_palette("Greens")[:1])
# Out:
# <AxesSubplot:xlabel='date_of', ylabel='agg_quan'>

# %% [markdown]
# ## Train Test Split

# %%
data_as_ts_train = data_real_sum_indexes[:-31]
data_as_ts_test = data_real_sum_indexes[len(data_as_ts_train):-1]
data_as_ts_final = data_real_sum_indexes[-1]

# %% [markdown]
# ## Regression

# %%
from statsmodels.tsa import stattools

# %%
def check_adf_stat(ts):
  df_stat = stattools.adfuller(ts)
  print('The Augmented Dickey-Fuller test statistic %f, \npvalue: %.2f\ncritical values: %s' %
        (df_stat[0], df_stat[1], df_stat[4]))

  if df_stat[0] > df_stat[4]['5%']:
      print('Есть единичные корни - ряд нестационарный')
  else:
      print('Единичных корней нет, ряд стационарен')

# %%
check_adf_stat(data_real_sum_indexes)
# Out:
# The Augmented Dickey-Fuller test statistic -47.385263,
# pvalue: 0.00
# critical values: {'1%': -3.4333712566259007, '5%': -2.8628746849930136, '10%': -2.567480519733324}
# Единичных корней нет, ряд стационарен

# %% [markdown]
# Наблюдаемый нами ряд стационарен

# %% [markdown]
# ### Autoreg

# %%
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

# %%
model = AutoReg(data_as_ts_train, lags = [1, 2, 3, 4, 5, 6, 7, 10, 20, 30, 100, 200, 365], trend='c').fit()
print(model.summary())
# Out:
# c:\Users\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                              AutoReg Model Results
# ===============================================================================
# Dep. Variable:                       y   No. Observations:                 2137
# Model:             Restr. AutoReg(365)   Log Likelihood               -7758.125
# Method:                Conditional MLE   S.D. of innovations             19.283
# Date:                 Sun, 31 Mar 2024   AIC                          15546.251
# Time:                         10:47:02   BIC                          15628.449
# Sample:                     04-09-2019   HQIC                         15576.617
#                           - 02-13-2024
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const
# AR.356           -0.0044           -1.0100j            1.0100           -0.2507
# AR.357           -0.0044           +1.0100j            1.0100            0.2507
# AR.358            0.0304           -1.0104j            1.0109           -0.2452
# AR.359            0.0304           +1.0104j            1.0109            0.2452
# AR.360            1.0090           -0.0442j            1.0100           -0.0070
# AR.361            1.0090           +0.0442j            1.0100            0.0070
# AR.362            1.0096           -0.0086j            1.0096           -0.0013
# AR.363            1.0096           +0.0086j            1.0096            0.0013
# AR.364            1.0101           -0.0257j            1.0104           -0.0041
# AR.365            1.0101           +0.0257j            1.0104            0.0041
# -------------------------------------------------------------------------------

# %%
y_hat = model.predict(start=0, end=len(data_real_sum_indexes)-1)
plt.figure(figsize=(10,4))
plt.plot(data_real_sum_indexes, label='data')
plt.plot(y_hat, label='AutoReg')
plt.legend(loc='best')
plt.title('AutoReg AllData')
plt.show()
print('RMSE = %.3f' % mean_squared_error(data_real_sum_indexes.values[365:], y_hat[365:]) ** 0.5)
print('MAPE = %.3f' % mean_absolute_percentage_error(data_real_sum_indexes.values[365:], y_hat[365:]) ** 0.5)
# Out:
# c:\Users\anaconda3\lib\site-packages\statsmodels\tsa\deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# RMSE = 19.294
# MAPE = 0.178

# %%
y_hat = model.predict(start=len(data_as_ts_train), end=(len(data_as_ts_train)+len(data_as_ts_test)-1))
plt.figure(figsize=(10,4))
plt.plot(data_as_ts_train.index[-100:], data_as_ts_train.values[-100:], label='X_train')
plt.plot(data_as_ts_test.index, data_as_ts_test.values, label='X_test')
plt.plot(data_as_ts_test.index, y_hat, label='AutoReg')
plt.legend(loc='best')
plt.title('AutoReg Forecast')
plt.show()
print('RMSE = %.3f' % mean_squared_error(data_as_ts_test.values, y_hat) ** 0.5)
print('MAPE = %.3f' % mean_absolute_percentage_error(data_as_ts_test.values, y_hat) ** 0.5)
# Out:
# c:\Users\anaconda3\lib\site-packages\statsmodels\tsa\deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# RMSE = 20.226
# MAPE = 0.184

# %%
y_hat_all_TS = model.predict(start=0, end=len(data_real_sum_indexes)-1)
# Out:
# c:\Users\anaconda3\lib\site-packages\statsmodels\tsa\deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)

# %%
data_anomaly_autoregression = (data_as_ts[365:]-y_hat_all_TS[365:])
data_anomaly_autoregression.plot(figsize = (20, 10))
# Out:
# <AxesSubplot:>

# %%
data_anomaly_autoregression.loc[data_anomaly_autoregression > -20].plot(figsize = (15, 5))
# Out:
# <AxesSubplot:>

# %%
data_anomaly_autoregression[22:]
# Out:
# 2019-04-09    -0.076697
# 2019-04-10   -10.730879
# 2019-04-11   -31.173131
# 2019-04-12    -8.187079
# 2019-04-13    38.586686
#                 ...
# 2024-03-11     5.842470
# 2024-03-12    -1.507099
# 2024-03-13    -0.478112
# 2024-03-14   -37.730805
# 2024-03-15    -4.637748
# Length: 1908, dtype: float64

# %%
df_num = pd.DataFrame(data_anomaly_autoregression[22:], columns = ['quotes_number'])
df_num ['date_of'] = df_num.index

# %%
from scipy import stats

plt.figure(figsize=(10, 6))
sns.scatterplot(x='date_of', y='quotes_number', data=df_num)
plt.title('я')
plt.xlabel('Дата')
plt.ylabel('Количество')

z_scores = stats.zscore(df_num['quotes_number'])
threshold = 1.2
outliers = df_num[(z_scores > threshold) | (z_scores < -threshold)]

# Отмечаем выбросы на графике
sns.scatterplot(x='date_of', y='quotes_number', data=outliers, color='red', label='Выбросы')
# Out:
# <AxesSubplot:title={'center':'я'}, xlabel='Дата', ylabel='Количество'>

# %% [markdown]
# # Pipeline + Гипотеза (НОВОЕ)

# %% [markdown]
# ## Гипотеза

# %% [markdown]
# Это - количество бенчмарков на определенный день, которые имеются в данных нашей совокупности временных рядов.

# %%
data_real_sum_indexes = pd.read_csv("data.csv", parse_dates=["date_of", "ctl_loading_date"]).groupby(["date_of"]).size()
data_real_sum_indexes.plot(figsize = (15, 5))
# Out:
# <AxesSubplot:xlabel='date_of'>

# %% [markdown]
# В данном ряду не наблюдается визуальных выбросов, значения распределены близко к нормальному. Более того, этот ряд является стационарным, что будет важно при обучении регрессионных моделей.

# %%
def check_adf_stat(ts):
  df_stat = stattools.adfuller(ts)
  print('The Augmented Dickey-Fuller test statistic %f, \npvalue: %.2f\ncritical values: %s' %
        (df_stat[0], df_stat[1], df_stat[4]))

  if df_stat[0] > df_stat[4]['5%']:
      print('Есть единичные корни - ряд нестационарный')
  else:
      print('Единичных корней нет, ряд стационарен')

check_adf_stat(data_real_sum_indexes)
# Out:
# The Augmented Dickey-Fuller test statistic -47.385263,
# pvalue: 0.00
# critical values: {'1%': -3.4333712566259007, '5%': -2.8628746849930136, '10%': -2.567480519733324}
# Единичных корней нет, ряд стационарен

# %%
sns.displot(data=data_real_sum_indexes, kind="kde")

# %% [markdown]
# А этот ряд - количество бенчмарков в посылке, соответствующий тому или иному дню индексов внутри неё.
#
# В день, когда приходило несколько небольших пакетов с индексами бралось максимальное значение из них - так как это не соответствует стандартной работе системы и скорее всего может рассматриваться как аномалия

# %%
data_as_ts = df_loadings[key_column]
data_as_ts.index = df_loadings['date_of'].map(pd.Timestamp)
data_as_ts = data_as_ts.sort_index()
#data_as_ts = data_as_ts.groupby(data_as_ts.index).min().reset_index()
#data_as_ts.set_index("date_of", inplace=True)
data_as_ts.plot(figsize = (15, 5))
# Out:
# <AxesSubplot:xlabel='date_of'>

# %% [markdown]
# Внутри ряда заметны очевидные выбросы. Ещё более они заметны если посмотреть на распределение ряда:

# %%
sns.displot(data=data_as_ts, kind="kde")

# %% [markdown]
# Но данные выбросы можно сделать ещё более заметными. Так, мы можем заметить, что в целом данные ряды кореллируют между собой:

# %%
import statistics

#R1 = statistics.correlation(data_as_ts.values, data_real_sum_indexes.values)
#print (f'R1 = {R1}, R2 = {R1**2}')

# %% [markdown]
# А если мы вычтем их друг из друга, то аномалии станут максимально заметны как на графике временного ряда, так и на графике распределения:

# %%
data_anomaly_detection = (data_as_ts - data_real_sum_indexes)
data_anomaly_detection.plot(figsize = (15, 5))
# Out:
# <AxesSubplot:xlabel='date_of'>

# %%
sns.displot(data=data_anomaly_detection, kind="kde")

# %% [markdown]
# #### Наша гипотеза заключается в следующем:
#
# 1. Данные по количеству бенчмарков на определенный день, которые имеются в данных нашей совокупности временных рядов являются стационарным рядом, который можно легко прогнозировать и на будущие периоды.
# 2. Разница между значениями ряда бенчмарков на определенный день и количеством бенчмарков в посылке, соответствующей определенному дню, является величиной, которая однозначно позволяет выявить аномалию статистическими методами.
#
# #### Таким образом, наше решение в рамках данной гипотезы будет состоять из следующих элементов:
#
# 1. Регрессионная модель для предсказания количества бенчмарков в посылке на определенный день.
# 2. Модель классификации аномалий, позволяющая оценить "нормальность" посылки по отклонению количества бенчмарков внутри неё от прогноза регрессионной модели.

# %% [markdown]
# ## Регрессионная модель

# %% [markdown]
# ### Train test split

# %% [markdown]
# Разобьем данные на тренировочные, тестовые и финальный прогноз на 15 число.

# %%
data_train = data_real_sum_indexes[:-31]
data_test = data_real_sum_indexes[len(data_as_ts_train):-1]
data_final = data_real_sum_indexes[-1]

# %% [markdown]
# ### Обучение модели

# %% [markdown]
# В качестве архитектуры будем использовать авторегрессионную модель с константным трендом, так как ряд является стационарным.

# %%
model = AutoReg(data_train, lags = [1, 2, 3, 4, 5, 6, 7, 10, 20, 30, 100, 200, 365], trend='c').fit()
print(model.summary())
# Out:
# c:\Users\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                              AutoReg Model Results
# ===============================================================================
# Dep. Variable:                       y   No. Observations:                 2137
# Model:             Restr. AutoReg(365)   Log Likelihood               -7758.125
# Method:                Conditional MLE   S.D. of innovations             19.283
# Date:                 Sun, 31 Mar 2024   AIC                          15546.251
# Time:                         10:47:09   BIC                          15628.449
# Sample:                     04-09-2019   HQIC                         15576.617
#                           - 02-13-2024
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        457.8430     39.107     11.707      0.000     381.194     534.492
# y.L1          -0.0081      0.024     -0.341      0.733      -0.055       0.038
# y.L2           0.0036      0.024      0.152      0.879      -0.043       0.050
# y.L3           0.0032      0.024      0.135      0.892      -0.043       0.050
# y.L4          -0.0285      0.024     -1.205      0.228      -0.075       0.018
# y.L5          -0.0079      0.024     -0.335      0.737      -0.054       0.039
# y.L6           0.0516      0.024      2.179      0.029       0.005       0.098
# y.L7           0.0198      0.024      0.835      0.404      -0.027       0.066
# y.L10          0.0059      0.024      0.248      0.804      -0.041       0.053
# y.L20         -0.0582      0.024     -2.452      0.014      -0.105      -0.012
# y.L30         -0.0077      0.024     -0.322      0.748      -0.055       0.039
# y.L100         0.0677      0.024      2.834      0.005       0.021       0.115
# y.L200        -0.0114      0.024     -0.478      0.633      -0.058       0.035
# y.L365        -0.0279      0.024     -1.157      0.247      -0.075       0.019
#                                      Roots
# ===============================================================================
#                     Real          Imaginary           Modulus         Frequency
# -------------------------------------------------------------------------------
# AR.1             -0.8118           -0.6005j            1.0097           -0.3986
# AR.2             -0.8118           +0.6005j            1.0097            0.3986
# AR.3             -0.8021           -0.6147j            1.0105           -0.3959
# AR.4             -0.8021           +0.6147j            1.0105            0.3959
# AR.5             -0.7904           -0.6290j            1.0101           -0.3930
# AR.6             -0.7904           +0.6290j            1.0101            0.3930
# AR.7             -0.7794           -0.6418j            1.0096           -0.3904
# AR.8             -0.7794           +0.6418j            1.0096            0.3904
# AR.9             -0.7685           -0.6547j            1.0096           -0.3877
# AR.10            -0.7685           +0.6547j            1.0096            0.3877
# AR.11            -0.7575           -0.6688j            1.0105           -0.3849
# AR.12            -0.7575           +0.6688j            1.0105            0.3849
# AR.13            -0.7448           -0.6813j            1.0094           -0.3821
# AR.14            -0.7448           +0.6813j            1.0094            0.3821
# AR.15            -0.7333           -0.6936j            1.0093           -0.3794
# AR.16            -0.7333           +0.6936j            1.0093            0.3794
# AR.17            -0.7220           -0.7059j            1.0097           -0.3768
# AR.18            -0.7220           +0.7059j            1.0097            0.3768
# AR.19            -0.7092           -0.7192j            1.0101           -0.3739
# AR.20            -0.7092           +0.7192j            1.0101            0.3739
# AR.21            -0.6965           -0.7304j            1.0093           -0.3712
# AR.127            0.8169           -0.5937j            1.0099           -0.1000
# AR.128            0.8169           +0.5937j            1.0099            0.1000
# AR.129            0.5691           -0.8350j            1.0105           -0.1548
# AR.130            0.5691           +0.8350j            1.0105            0.1548
# AR.131           -0.9319           -0.3891j            1.0099           -0.4371
# AR.132           -0.9319           +0.3891j            1.0099            0.4371
# AR.133           -0.3933           -0.9302j            1.0099           -0.3137
# AR.134           -0.3933           +0.9302j            1.0099            0.3137
# AR.135            0.5536           -0.8442j            1.0096           -0.1576
# AR.136            0.5536           +0.8442j            1.0096            0.1576
# AR.137            0.8269           -0.5800j            1.0100           -0.0974
# AR.138            0.8269           +0.5800j            1.0100            0.0974
# AR.139            0.5393           -0.8533j            1.0094           -0.1603
# AR.140            0.5393           +0.8533j            1.0094            0.1603
# AR.141            0.8378           -0.5654j            1.0107           -0.0945
# AR.142            0.8378           +0.5654j            1.0107            0.0945
# AR.143            0.8466           -0.5503j            1.0097           -0.0917
# AR.144            0.8466           +0.5503j            1.0097            0.0917
# AR.145            0.5252           -0.8623j            1.0097           -0.1629
# AR.146            0.5252           +0.8623j            1.0097            0.1629
# AR.147           -0.9381           -0.3734j            1.0097           -0.4397
# AR.148           -0.9381           +0.3734j            1.0097            0.4397
# AR.149           -0.3775           -0.9361j            1.0094           -0.3110
# AR.150           -0.3775           +0.9361j            1.0094            0.3110
# AR.151            0.5097           -0.8722j            1.0102           -0.1658
# AR.152            0.5097           +0.8722j            1.0102            0.1658
# AR.153            0.8557           -0.5359j            1.0097           -0.0890
# AR.154            0.8557           +0.5359j            1.0097            0.0890
# AR.155            0.8651           -0.5218j            1.0103           -0.0864
# AR.156            0.8651           +0.5218j            1.0103            0.0864
# AR.157            0.4943           -0.8798j            1.0092           -0.1685
# AR.158            0.4943           +0.8798j            1.0092            0.1685
# AR.159            0.4795           -0.8880j            1.0091           -0.1712
# AR.160            0.4795           +0.8880j            1.0091            0.1712
# AR.161            0.8744           -0.5058j            1.0102           -0.0835
# AR.162            0.8744           +0.5058j            1.0102            0.0835
# AR.163           -0.9443           -0.3577j            1.0098           -0.4424
# AR.164           -0.9443           +0.3577j            1.0098            0.4424
# AR.165           -0.3617           -0.9425j            1.0095           -0.3083
# AR.166           -0.3617           +0.9425j            1.0095            0.3083
# AR.167            0.4649           -0.8967j            1.0100           -0.1739
# AR.168            0.4649           +0.8967j            1.0100            0.1739
# AR.169            0.4483           -0.9047j            1.0096           -0.1768
# AR.170            0.4483           +0.9047j            1.0096            0.1768
# AR.171            0.8822           -0.4908j            1.0095           -0.0808
# AR.172            0.8822           +0.4908j            1.0095            0.0808
# AR.173            0.8902           -0.4760j            1.0095           -0.0781
# AR.174            0.8902           +0.4760j            1.0095            0.0781
# AR.175           -0.9514           -0.3411j            1.0107           -0.4452
# AR.176           -0.9514           +0.3411j            1.0107            0.4452
# AR.177            0.4331           -0.9116j            1.0092           -0.1794
# AR.178            0.4331           +0.9116j            1.0092            0.1794
# AR.179           -0.9563           -0.3241j            1.0097           -0.4480
# AR.180           -0.9563           +0.3241j            1.0097            0.4480
# AR.181           -0.3457           -0.9496j            1.0106           -0.3056
# AR.182           -0.3457           +0.9496j            1.0106            0.3056
# AR.183            0.8993           -0.4609j            1.0105           -0.0754
# AR.184            0.8993           +0.4609j            1.0105            0.0754
# AR.185            0.4179           -0.9188j            1.0094           -0.1821
# AR.186            0.4179           +0.9188j            1.0094            0.1821
# AR.187            0.9066           -0.4444j            1.0097           -0.0725
# AR.188            0.9066           +0.4444j            1.0097            0.0725
# AR.189            0.4021           -0.9270j            1.0104           -0.1849
# AR.190            0.4021           +0.9270j            1.0104            0.1849
# AR.191           -0.3283           -0.9549j            1.0098           -0.3027
# AR.192           -0.3283           +0.9549j            1.0098            0.3027
# AR.193            0.9138           -0.4293j            1.0096           -0.0699
# AR.194            0.9138           +0.4293j            1.0096            0.0699
# AR.195           -0.9617           -0.3079j            1.0097           -0.4507
# AR.196           -0.9617           +0.3079j            1.0097            0.4507
# AR.197           -0.3122           -0.9602j            1.0097           -0.3000
# AR.198           -0.3122           +0.9602j            1.0097            0.3000
# AR.199            0.3853           -0.9331j            1.0095           -0.1877
# AR.200            0.3853           +0.9331j            1.0095            0.1877
# AR.201            0.9211           -0.4141j            1.0099           -0.0672
# AR.202            0.9211           +0.4141j            1.0099            0.0672
# AR.203            0.3697           -0.9395j            1.0096           -0.1903
# AR.204            0.3697           +0.9395j            1.0096            0.1903
# AR.205           -0.9671           -0.2919j            1.0102           -0.4533
# AR.206           -0.9671           +0.2919j            1.0102            0.4533
# AR.207            0.9291           -0.3976j            1.0106           -0.0644
# AR.208            0.9291           +0.3976j            1.0106            0.0644
# AR.209            0.3541           -0.9460j            1.0101           -0.1930
# AR.210            0.3541           +0.9460j            1.0101            0.1930
# AR.211            0.9349           -0.3813j            1.0097           -0.0616
# AR.212            0.9349           +0.3813j            1.0097            0.0616
# AR.213           -0.2962           -0.9655j            1.0099           -0.2974
# AR.214           -0.2962           +0.9655j            1.0099            0.2974
# AR.215            0.9413           -0.3654j            1.0098           -0.0589
# AR.216            0.9413           +0.3654j            1.0098            0.0589
# AR.217           -0.9725           -0.2742j            1.0104           -0.4563
# AR.218           -0.9725           +0.2742j            1.0104            0.4563
# AR.219           -0.9762           -0.2575j            1.0096           -0.4590
# AR.220           -0.9762           +0.2575j            1.0096            0.4590
# AR.221            0.3369           -0.9527j            1.0105           -0.1959
# AR.222            0.3369           +0.9527j            1.0105            0.1959
# AR.223           -0.2788           -0.9713j            1.0106           -0.2945
# AR.224           -0.2788           +0.9713j            1.0106            0.2945
# AR.225            0.3204           -0.9576j            1.0098           -0.1986
# AR.226            0.3204           +0.9576j            1.0098            0.1986
# AR.227            0.9481           -0.3498j            1.0105           -0.0563
# AR.228            0.9481           +0.3498j            1.0105            0.0563
# AR.229           -0.9804           -0.2409j            1.0095           -0.4616
# AR.230           -0.9804           +0.2409j            1.0095            0.4616
# AR.231           -0.2618           -0.9750j            1.0095           -0.2917
# AR.232           -0.2618           +0.9750j            1.0095            0.2917
# AR.233            0.3041           -0.9629j            1.0098           -0.2013
# AR.234            0.3041           +0.9629j            1.0098            0.2013
# AR.235            0.9541           -0.3323j            1.0103           -0.0533
# AR.236            0.9541           +0.3323j            1.0103            0.0533
# AR.237            0.2879           -0.9688j            1.0106           -0.2040
# AR.238            0.2879           +0.9688j            1.0106            0.2040
# AR.239            0.9591           -0.3161j            1.0099           -0.0507
# AR.240            0.9591           +0.3161j            1.0099            0.0507
# AR.241            0.9643           -0.2998j            1.0098           -0.0480
# AR.242            0.9643           +0.2998j            1.0098            0.0480
# AR.243           -0.2453           -0.9793j            1.0095           -0.2891
# AR.244           -0.2453           +0.9793j            1.0095            0.2891
# AR.245           -0.9852           -0.2243j            1.0104           -0.4644
# AR.246           -0.9852           +0.2243j            1.0104            0.4644
# AR.247           -0.2290           -0.9838j            1.0101           -0.2864
# AR.248           -0.2290           +0.9838j            1.0101            0.2864
# AR.249           -0.9884           -0.2063j            1.0097           -0.4673
# AR.250           -0.9884           +0.2063j            1.0097            0.4673
# AR.251            0.2700           -0.9734j            1.0101           -0.2069
# AR.252            0.2700           +0.9734j            1.0101            0.2069
# AR.253            0.2536           -0.9774j            1.0098           -0.2096
# AR.254            0.2536           +0.9774j            1.0098            0.2096
# AR.255            0.9703           -0.2832j            1.0108           -0.0452
# AR.256            0.9703           +0.2832j            1.0108            0.0452
# AR.257            0.9743           -0.2656j            1.0099           -0.0424
# AR.258            0.9743           +0.2656j            1.0099            0.0424
# AR.259           -0.2109           -0.9877j            1.0100           -0.2835
# AR.260           -0.2109           +0.9877j            1.0100            0.2835
# AR.261            0.2372           -0.9815j            1.0097           -0.2123
# AR.262            0.2372           +0.9815j            1.0097            0.2123
# AR.263            0.9785           -0.2491j            1.0097           -0.0397
# AR.264            0.9785           +0.2491j            1.0097            0.0397
# AR.265           -0.9914           -0.1898j            1.0094           -0.4699
# AR.266           -0.9914           +0.1898j            1.0094            0.4699
# AR.267           -0.1944           -0.9905j            1.0094           -0.2808
# AR.268           -0.1944           +0.9905j            1.0094            0.2808
# AR.269            0.2200           -0.9864j            1.0106           -0.2151
# AR.270            0.2200           +0.9864j            1.0106            0.2151
# AR.271           -0.9945           -0.1733j            1.0095           -0.4725
# AR.272           -0.9945           +0.1733j            1.0095            0.4725
# AR.273            0.9827           -0.2329j            1.0099           -0.0370
# AR.274            0.9827           +0.2329j            1.0099            0.0370
# AR.275            0.2024           -0.9891j            1.0096           -0.2179
# AR.276            0.2024           +0.9891j            1.0096            0.2179
# AR.277            0.9873           -0.2151j            1.0104           -0.0341
# AR.278            0.9873           +0.2151j            1.0104            0.0341
# AR.279           -0.1778           -0.9936j            1.0094           -0.2782
# AR.280           -0.1778           +0.9936j            1.0094            0.2782
# AR.281           -0.9983           -0.1556j            1.0103           -0.4754
# AR.282           -0.9983           +0.1556j            1.0103            0.4754
# AR.283            0.9898           -0.1980j            1.0094           -0.0314
# AR.284            0.9898           +0.1980j            1.0094            0.0314
# AR.285            0.1859           -0.9923j            1.0096           -0.2205
# AR.286            0.1859           +0.9923j            1.0096            0.2205
# AR.287           -0.1607           -0.9976j            1.0105           -0.2754
# AR.288           -0.1607           +0.9976j            1.0105            0.2754
# AR.289            0.9929           -0.1813j            1.0093           -0.0287
# AR.290            0.9929           +0.1813j            1.0093            0.0287
# AR.291            0.1694           -0.9957j            1.0100           -0.2232
# AR.292            0.1694           +0.9957j            1.0100            0.2232
# AR.293           -1.0097           -0.0000j            1.0097           -0.5000
# AR.294           -0.9998           -0.1382j            1.0093           -0.4781
# AR.295           -0.9998           +0.1382j            1.0093            0.4781
# AR.296            0.9966           -0.1648j            1.0101           -0.0261
# AR.297            0.9966           +0.1648j            1.0101            0.0261
# AR.298           -0.1427           -0.9995j            1.0096           -0.2726
# AR.299           -0.1427           +0.9995j            1.0096            0.2726
# AR.300            0.1344           -1.0006j            1.0096           -0.2288
# AR.301            0.1344           +1.0006j            1.0096            0.2288
# AR.302            0.1513           -0.9990j            1.0104           -0.2261
# AR.303            0.1513           +0.9990j            1.0104            0.2261
# AR.304           -1.0019           -0.1215j            1.0093           -0.4808
# AR.305           -1.0019           +0.1215j            1.0093            0.4808
# AR.306           -0.1261           -1.0017j            1.0096           -0.2699
# AR.307           -0.1261           +1.0017j            1.0096            0.2699
# AR.308           -0.1094           -1.0040j            1.0100           -0.2673
# AR.309           -0.1094           +1.0040j            1.0100            0.2673
# AR.310            0.1175           -1.0028j            1.0097           -0.2314
# AR.311            0.1175           +1.0028j            1.0097            0.2314
# AR.312            0.9991           -0.1465j            1.0098           -0.0232
# AR.313            0.9991           +0.1465j            1.0098            0.0232
# AR.314            1.0009           -0.1299j            1.0093           -0.0205
# AR.315            1.0009           +0.1299j            1.0093            0.0205
# AR.316            1.0030           -0.1132j            1.0093           -0.0179
# AR.317            1.0030           +0.1132j            1.0093            0.0179
# AR.318           -1.0045           -0.1049j            1.0100           -0.4834
# AR.319           -1.0045           +0.1049j            1.0100            0.4834
# AR.320           -1.0064           -0.0864j            1.0101           -0.4864
# AR.321           -1.0064           +0.0864j            1.0101            0.4864
# AR.322            0.1004           -1.0056j            1.0106           -0.2342
# AR.323            0.1004           +1.0056j            1.0106            0.2342
# AR.324           -1.0071           -0.0696j            1.0095           -0.4890
# AR.325           -1.0071           +0.0696j            1.0095            0.4890
# AR.326            0.0821           -1.0068j            1.0101           -0.2370
# AR.327            0.0821           +1.0068j            1.0101            0.2370
# AR.328            1.0065           -0.0778j            1.0095           -0.0123
# AR.329            1.0065           +0.0778j            1.0095            0.0123
# AR.330            1.0059           -0.0957j            1.0104           -0.0151
# AR.331            1.0059           +0.0957j            1.0104            0.0151
# AR.332           -0.0912           -1.0065j            1.0106           -0.2644
# AR.333           -0.0912           +1.0065j            1.0106            0.2644
# AR.334           -1.0082           -0.0526j            1.0096           -0.4917
# AR.335           -1.0082           +0.0526j            1.0096            0.4917
# AR.336           -1.0097           -0.0169j            1.0099           -0.4973
# AR.337           -1.0097           +0.0169j            1.0099            0.4973
# AR.338           -1.0100           -0.0352j            1.0106           -0.4945
# AR.339           -1.0100           +0.0352j            1.0106            0.4945
# AR.340            1.0077           -0.0610j            1.0095           -0.0096
# AR.341            1.0077           +0.0610j            1.0095            0.0096
# AR.342            0.0653           -1.0078j            1.0099           -0.2397
# AR.343            0.0653           +1.0078j            1.0099            0.2397
# AR.344           -0.0740           -1.0070j            1.0097           -0.2617
# AR.345           -0.0740           +1.0070j            1.0097            0.2617
# AR.346            0.0483           -1.0089j            1.0100           -0.2424
# AR.347            0.0483           +1.0089j            1.0100            0.2424
# AR.348            0.0127           -1.0099j            1.0100           -0.2480
# AR.349            0.0127           +1.0099j            1.0100            0.2480
# AR.350           -0.0569           -1.0083j            1.0099           -0.2590
# AR.351           -0.0569           +1.0083j            1.0099            0.2590
# AR.352           -0.0214           -1.0102j            1.0104           -0.2534
# AR.353           -0.0214           +1.0102j            1.0104            0.2534
# AR.354           -0.0399           -1.0098j            1.0106           -0.2563
# AR.355           -0.0399           +1.0098j            1.0106            0.2563
# AR.356           -0.0044           -1.0100j            1.0100           -0.2507
# AR.357           -0.0044           +1.0100j            1.0100            0.2507
# AR.358            0.0304           -1.0104j            1.0109           -0.2452
# AR.359            0.0304           +1.0104j            1.0109            0.2452
# AR.360            1.0090           -0.0442j            1.0100           -0.0070
# AR.361            1.0090           +0.0442j            1.0100            0.0070
# AR.362            1.0096           -0.0086j            1.0096           -0.0013
# AR.363            1.0096           +0.0086j            1.0096            0.0013
# AR.364            1.0101           -0.0257j            1.0104           -0.0041
# AR.365            1.0101           +0.0257j            1.0104            0.0041
# -------------------------------------------------------------------------------

# %% [markdown]
# Параметры модели

# %%
model.params
# Out:
# const     457.842964
# y.L1       -0.008090
# y.L2        0.003597
# y.L3        0.003208
# y.L4       -0.028543
# y.L5       -0.007948
# y.L6        0.051609
# y.L7        0.019792
# y.L10       0.005892
# y.L20      -0.058242
# y.L30      -0.007700
# y.L100      0.067695
# y.L200     -0.011405
# y.L365     -0.027850
# dtype: float64

# %% [markdown]
# ### Прогнозы модели

# %%
y_hat = model.predict(start=0, end=len(data_real_sum_indexes)-1)
plt.figure(figsize=(10,4))
plt.plot(data_real_sum_indexes.index, data_real_sum_indexes.values, label='data')
plt.plot(data_real_sum_indexes.index, y_hat, label='AutoReg')
plt.legend(loc='best')
plt.title('AutoReg AllData')
plt.show()
print('МЕТРИКИ:')
print('RMSE = %.3f' % mean_squared_error(data_real_sum_indexes.values[365:], y_hat[365:]) ** 0.5)
print('MAPE = %.3f' % mean_absolute_percentage_error(data_real_sum_indexes.values[365:], y_hat[365:]) ** 0.5)
# Out:
# c:\Users\anaconda3\lib\site-packages\statsmodels\tsa\deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# МЕТРИКИ:
# RMSE = 19.294
# MAPE = 0.178

# %%
y_hat = model.predict(start=len(data_train), end=(len(data_train)+len(data_test)-1))
plt.figure(figsize=(10,4))
plt.plot(data_train.index[-100:], data_train.values[-100:], label='X_train')
plt.plot(data_test.index, data_test.values, label='X_test')
plt.plot(data_test.index, y_hat, label='AutoReg')
plt.legend(loc='best')
plt.title('AutoReg Forecast')
plt.show()
print('RMSE = %.3f' % mean_squared_error(data_as_ts_test.values, y_hat) ** 0.5)
print('MAPE = %.3f' % mean_absolute_percentage_error(data_as_ts_test.values, y_hat) ** 0.5)
# Out:
# c:\Users\anaconda3\lib\site-packages\statsmodels\tsa\deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# RMSE = 20.226
# MAPE = 0.184

# %% [markdown]
# ## Детекция аномалий

# %% [markdown]
# ### На всем временном ряду:

# %%
y_hat_all_TS = model.predict(start=0, end=len(data_real_sum_indexes)-1)
data_anomaly_autoregression = (y_hat_all_TS[365:]-data_as_ts[365:])
data_anomaly_autoregression.plot(figsize = (20,10))
# Out:
# c:\Users\anaconda3\lib\site-packages\statsmodels\tsa\deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)
# <AxesSubplot:>

# %% [markdown]
# #### Z-score

# %%
sns.displot(data=data_anomaly_autoregression, kind="kde")

# %% [markdown]
# Как мы видим - распределение близко к нормальному. А значит в качестве метрики для "отсечения" аномальных точек" в генеральной совокупности мы можем использовать Z-score точек.

# %%
df_num = pd.DataFrame(data_anomaly_autoregression[22:], columns = ['quotes_number'])
df_num ['date_of'] = df_num.index

# %%
from scipy import stats

plt.figure(figsize=(12, 5))
sns.scatterplot(x='date_of', y='quotes_number', data=df_num)
plt.title('')
plt.xlabel('')
plt.ylabel('')

z_scores = stats.zscore(df_num['quotes_number'])
threshold = 1.8
outliers = df_num[(z_scores > threshold) | (z_scores < -threshold)]

# Отмечаем выбросы на графике
sns.scatterplot(x='date_of', y='quotes_number', data=outliers, color='green')
# Out:
# <AxesSubplot:xlabel='date_of', ylabel='quotes_number'>

# %% [markdown]
# #### DBSCAN

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
dataset = df_num["quotes_number"].reset_index()
dataset["index"] = dataset["index"].astype(np.int64)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1908 entries, 0 to 1907
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          1908 non-null   int64
#  1   quotes_number  1908 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 29.9 KB

# %%
clusterizator = DBSCAN(min_samples=10).fit(StandardScaler().fit_transform(X=dataset,y=None))
clusterizator.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
plt.figure(figsize=(10, 6))
palete = ['yellow', 'skyblue']
sns.scatterplot(data=dataset, x="index", y="quotes_number", hue = clusterizator.labels_, palette = palete, edgecolor = 'black')
plt.title('DBSCAN')
plt.xlabel('Дата')
plt.ylabel('Количество')
# Out:
# Text(0, 0.5, 'Количество')

# %% [markdown]
# ### На новых данных

# %% [markdown]
# Таким образом, для новых данных алгоритм будет работать следующим образом:
#
# 1. Принимает на вход пары вида ["дата посылки", "объем посылки"]
# 2. По дате посылки оценивает ожидаемый объем посылки через авторегрессионную модель
# 3. Сравнивает разницу между фактическим объемом посылки и ожидаемым объемом посылки с генеральной совокупность, отсекает данные с помощью one class SVM

# %%
def predict_labels (data):
# Out:
#   Input In [398]
#
#     ^
# IndentationError: expected an indented block

# %%
df = pd.read_csv("data.csv", parse_dates=["date_of", "ctl_loading_date"])

date_sz = df.groupby(["date_of"]).size()
date_sz
# Out:
# date_of
# 2018-04-09    435
# 2018-04-10    476
# 2018-04-11    458
# 2018-04-12    443
# 2018-04-13    458
#              ...
# 2024-03-11    467
# 2024-03-12    458
# 2024-03-13    458
# 2024-03-14    422
# 2024-03-15    458
# Length: 2168, dtype: int64
